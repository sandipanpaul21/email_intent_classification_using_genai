# %% [markdown]
# ![NLP Cheatsheet Part 1 NLP Basics.png](<attachment:NLP Cheatsheet Part 1 NLP Basics.png>)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize


data = pd.read_csv("../data/fd_dataset_messy.csv")
print(data.head(5))
# Out:
#                          email                 time        subject  \
# 0  mukesh.bhatt@rediffmail.com  2025-02-17 20:29:47  Payment issue
# 1      sanjay.jain@hotmail.com  2024-06-07 16:22:21           Help
# 2         ashok.nair@gmail.com  2024-04-05 08:16:39     Loan query
# 3    manoj.gupta51@hotmail.com  2025-01-04 23:24:05          Query
# 4     vinod.chopra87@gmail.com  2025-03-03 10:12:43    Loan status
#
#                                              content              label
# 0  Branch gaya tha, unhone email karne bola. Two ...             Non-FD
# 1  Dear customer care, My insurance policy is rea...             Non-FD
# 2  Namaskar, Rs 6 lakh kat gaya bina bataye insur...             Non-FD
# 3  Dear customer care, 1. Suna hai Bajaj Finance ...  Multiple Category
# 4  Dear customer care, Where is my money? The rev...             Non-FD

# %%
content_token = []

for text in data['content']:
    tokens = word_tokenize(str(text))
    content_token.append(tokens)

data['content_token'] = content_token
print("First Email Content:", data['content'][0])
print("First Email Content Tokens:", content_token[0])
# Out:
# First Email Content: Branch gaya tha, unhone email karne bola. Two wheeler loan ki EMI is mahine zyada kati hai. Pehle se Rs 800 jyada. Kyu? Statement bhejo. Bahut pareshan ho gaya hoon. Mukesh Bhatt
# First Email Content Tokens: ['Branch', 'gaya', 'tha', ',', 'unhone', 'email', 'karne', 'bola', '.', 'Two', 'wheeler', 'loan', 'ki', 'EMI', 'is', 'mahine', 'zyada', 'kati', 'hai', '.', 'Pehle', 'se', 'Rs', '800', 'jyada', '.', 'Kyu', '?', 'Statement', 'bhejo', '.', 'Bahut', 'pareshan', 'ho', 'gaya', 'hoon', '.', 'Mukesh', 'Bhatt']

# %%
print(data.head(5))
# Out:
#                          email                 time        subject  \
# 0  mukesh.bhatt@rediffmail.com  2025-02-17 20:29:47  Payment issue
# 1      sanjay.jain@hotmail.com  2024-06-07 16:22:21           Help
# 2         ashok.nair@gmail.com  2024-04-05 08:16:39     Loan query
# 3    manoj.gupta51@hotmail.com  2025-01-04 23:24:05          Query
# 4     vinod.chopra87@gmail.com  2025-03-03 10:12:43    Loan status
#
#                                              content              label  \
# 0  Branch gaya tha, unhone email karne bola. Two ...             Non-FD
# 1  Dear customer care, My insurance policy is rea...             Non-FD
# 2  Namaskar, Rs 6 lakh kat gaya bina bataye insur...             Non-FD
# 3  Dear customer care, 1. Suna hai Bajaj Finance ...  Multiple Category
# 4  Dear customer care, Where is my money? The rev...             Non-FD
#
#                                        content_token
# 0  [Branch, gaya, tha, ,, unhone, email, karne, b...
# 1  [Dear, customer, care, ,, My, insurance, polic...
# 2  [Namaskar, ,, Rs, 6, lakh, kat, gaya, bina, ba...
# 3  [Dear, customer, care, ,, 1, ., Suna, hai, Baj...
# 4  [Dear, customer, care, ,, Where, is, my, money...
