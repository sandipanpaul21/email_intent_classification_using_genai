# %% [markdown]
# OCR team converts PDFs to JSON format.a
# We initially tried but facing issues with table format, Broken table structure , Mixed documents, Encrypted/password-protected PDFs , Broken table structure , Corrupted files
#
#
# Through Azure blob, we download all latest files if there is any and check for duplicate content
